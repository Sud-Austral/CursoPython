# %%
# storing and anaysis
import numpy as np
import pandas as pd

# visualization
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import folium
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-476c5aa18e51> in <module>()
#       6 import matplotlib.pyplot as plt
#       7 import seaborn as sns
# ----> 8 import plotly.express as px
#       9 import folium
#
# ModuleNotFoundError: No module named 'plotly'

# %%
#dataConfirmados = pd.read_csv("../datasets/Corona/time_series_2019_ncov_confirmed.csv")
#dataMuertos = pd.read_csv("../datasets/Corona/time_series_2019_ncov_deaths.csv")
#dataRecuperados = pd.read_csv("../datasets/Corona/time_series_2019_ncov_recovered.csv")

conf_df = pd.read_csv("../datasets/Corona/time_series_2019_ncov_confirmed.csv")
deaths_df = pd.read_csv("../datasets/Corona/time_series_2019_ncov_deaths.csv")
recv_df = pd.read_csv("../datasets/Corona/time_series_2019_ncov_recovered.csv")

conf_df.head()
# Out:
#   Province/State  Country/Region       Lat      Long  1/21/20 22:00  \
# 0          Anhui  Mainland China  31.82571  117.2264            NaN
# 1        Beijing  Mainland China  40.18238  116.4142           10.0
# 2      Chongqing  Mainland China  30.05718  107.8740            5.0
# 3         Fujian  Mainland China  26.07783  117.9895            NaN
# 4          Gansu  Mainland China  36.06110  103.8343            NaN
#
#    1/22/20 12:00  1/23/20 12:00  1/24/20 0:00  1/24/20 12:00  1/25/20 0:00  \
# 0            1.0            9.0          15.0           15.0          39.0
# 1           14.0           22.0          26.0           36.0          36.0
# 2            6.0            9.0          27.0           27.0          57.0
# 3            1.0            5.0           5.0           10.0          10.0
# 4            NaN            2.0           2.0            2.0           4.0
#
#         ...        02/05/20 9:00  02/05/20 23:00  02/06/20 9:00  \
# ...

# %%
dates = ['1/22/20', '1/23/20', '1/24/20', '1/25/20', '1/26/20', '1/27/20', '1/28/20', 
         '1/29/20', '1/30/20', '1/31/20', '2/1/20', '2/2/20', '2/3/20', '2/4/20', 
         '2/5/20', '2/6/20', '2/7/20', '2/8/20', '2/9/20']

conf_df_long = conf_df.melt(id_vars=['Province/State', 'Country/Region', 'Lat', 'Long'], 
                            value_vars=dates, var_name='Date', value_name='Confirmed')

deaths_df_long = deaths_df.melt(id_vars=['Province/State', 'Country/Region', 'Lat', 'Long'], 
                            value_vars=dates, var_name='Date', value_name='Deaths')

recv_df_long = recv_df.melt(id_vars=['Province/State', 'Country/Region', 'Lat', 'Long'], 
                            value_vars=dates, var_name='Date', value_name='Recovered')

full_table = pd.concat([conf_df_long, deaths_df_long['Deaths'], recv_df_long['Recovered']], 
                       axis=1, sort=False)
full_table.head()
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\pandas\core\indexing.py:1472: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
#   Province/State  Country/Region       Lat      Long     Date  Confirmed  \
# 0          Anhui  Mainland China  31.82571  117.2264  1/22/20        NaN
# 1        Beijing  Mainland China  40.18238  116.4142  1/22/20        NaN
# 2      Chongqing  Mainland China  30.05718  107.8740  1/22/20        NaN
# 3         Fujian  Mainland China  26.07783  117.9895  1/22/20        NaN
# 4          Gansu  Mainland China  36.06110  103.8343  1/22/20        NaN
#
#    Deaths  Recovered
# 0     NaN        NaN
# 1     NaN        NaN
# 2     NaN        NaN
# 3     NaN        NaN
# ...

# %%
# converting to proper data format
full_table['Date'] = pd.to_datetime(full_table['Date'])
full_table['Recovered'] = full_table['Recovered'].astype('int')

# replacing Mainland china with just China
full_table['Country/Region'] = full_table['Country/Region'].replace('Mainland China', 'China')

# filling missing values with 0 in columns ('Confirmed', 'Deaths', 'Recovered')
full_table[['Confirmed', 'Deaths', 'Recovered']] = full_table[['Confirmed', 'Deaths', 'Recovered']].fillna(0)
full_table[['Province/State']] = full_table[['Province/State']].fillna('NA')

# cases in the Diamond Princess cruise ship
ship = full_table[full_table['Province/State']=='Diamond Princess cruise ship']

# full table
full_table = full_table[full_table['Province/State']!='Diamond Princess cruise ship']
full_table.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-59a156fcb9ae> in <module>()
#       1 # converting to proper data format
#       2 full_table['Date'] = pd.to_datetime(full_table['Date'])
# ----> 3 full_table['Recovered'] = full_table['Recovered'].astype('int')
#       4
#       5 # replacing Mainland china with just China
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     175                 else:
#     176                     kwargs[new_arg_name] = new_arg_value
# --> 177             return func(*args, **kwargs)
#     178         return wrapper
#     179     return _deprecate_kwarg
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
# ...
