# %% [markdown]
# # Carga de datos a traves de la funcion read_csv

# %%
#Autocompletar con tab
# %config IPCompleter.greedy=True

# %% [markdown]
# Cuando en Windows queremos utilizar una instrucción como por ejemplo
# pandas.read_cvs("C:\user\titanic3.cvs")
# se debe hacer con las barras "/" y no con "\".
#
# Alternativamente, lo otro que podemos hacer es colocar un "r" antes de la ruta
# de la siguiente forma:
# pandas.read_cvs(r"C:\user\titanic3.cvs")
# y asi no tenemos que cambiar las "\".

# %%
#Importar Pandas
import pandas as pd
import os

# %%
#Leer los datos
data = pd.read_csv("../datasets/titanic/titanic3.csv")

# %%
# Ver datos
#print(data) 
data.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %% [markdown]
# ### Ejemplos de los parametros de la funcion read_csv
# read_csv(filepath="../datasets/titanic/titanic3.csv",
#          sep=",",
#          dtype={"ingresos":np.float64, "edad":np.int32},
#          header=0,
#          names={"ingresos", "edad"},
#          skiprows=12,
#          index_col=None,
#          skip_blank_lines=True,
#          na_filter=False,
#         )

# %%
mainpath = "C:/Users/limc_/OneDrive/Documentos/GitHub/CursoPython/Luis/datasets"
filename = "titanic/titanic3.csv"
#fullpath = mainpath + "/" + filename
fullpath =os.path.join(mainpath,fullpath)
data = pd.read_csv(fullpath)

# %%
data.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %%
data2 = pd.read_csv(mainpath + "/" + "customer-churn-model/Customer Churn Model.txt")

# %%
data2.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge   ...    Eve Calls  \
# 0             25     265.1        110       45.07   ...           99
# 1             26     161.6        123       27.47   ...          103
# 2              0     243.4        114       41.38   ...          110
# 3              0     299.4         71       50.90   ...           88
# 4              0     166.7        113       28.34   ...          122
#
#    Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  \
# 0       16.78       244.7           91         11.01       10.0           3
# 1       16.62       254.4          103         11.45       13.7           3
# 2       10.30       162.6          104          7.32       12.2           5
# 3        5.26       196.9           89          8.86        6.6           7
# 4       12.61       186.9          121          8.41       10.1           3
#
#    Intl Charge  CustServ Calls  Churn?
# 0         2.70               1  False.
# 1         3.70               1  False.
# 2         3.29               0  False.
# 3         1.78               2  False.
# 4         2.73               3  False.
#
# [5 rows x 21 columns]

# %%
data2.columns.values
# Out:
# array(['State', 'Account Length', 'Area Code', 'Phone', "Int'l Plan",
#        'VMail Plan', 'VMail Message', 'Day Mins', 'Day Calls',
#        'Day Charge', 'Eve Mins', 'Eve Calls', 'Eve Charge', 'Night Mins',
#        'Night Calls', 'Night Charge', 'Intl Mins', 'Intl Calls',
#        'Intl Charge', 'CustServ Calls', 'Churn?'], dtype=object)

# %%
data_cols = pd.read_csv(mainpath + "/" + "customer-churn-model/Customer Churn Columns.csv")
data_col_list = data_cols["Column_Names"].tolist()
data_col_list
data2 = pd.read_csv(mainpath + "/" + "customer-churn-model/Customer Churn Model.txt", 
                    header = None, 
                    names = data_col_list )

# %%
data2.head()
# Out:
#        A               B          C         D           E           F  \
# 0  State  Account Length  Area Code     Phone  Int'l Plan  VMail Plan
# 1     KS             128        415  382-4657          no         yes
# 2     OH             107        415  371-7191          no         yes
# 3     NJ             137        415  358-1921          no          no
# 4     OH              84        408  375-9999         yes          no
# 5     OK              75        415  330-6626         yes          no
#
#                G           H          I           J   ...            L  \
# 0  VMail Message    Day Mins  Day Calls  Day Charge   ...    Eve Calls
# 1             25  265.100000        110   45.070000   ...           99
# 2             26  161.600000        123   27.470000   ...          103
# 3              0  243.400000        114   41.380000   ...          110
# 4              0  299.400000         71   50.900000   ...           88
# 5              0  166.700000        113   28.340000   ...          122
#
#             M           N            O             P          Q           R  \
# 0  Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls
# 1   16.780000  244.700000           91     11.010000  10.000000           3
# 2   16.620000  254.400000          103     11.450000  13.700000           3
# 3   10.300000  162.600000          104      7.320000  12.200000           5
# 4    5.260000  196.900000           89      8.860000   6.600000           7
# 5   12.610000  186.900000          121      8.410000  10.100000           3
#
#              S               T       U
# 0  Intl Charge  CustServ Calls  Churn?
# 1     2.700000               1  False.
# 2     3.700000               1  False.
# 3     3.290000               0  False.
# 4     1.780000               2  False.
# 5     2.730000               3  False.
#
# [6 rows x 21 columns]

# %% [markdown]
# ### Carga de datos a traves de la funcion open

# %%
data3 = open(mainpath + "/" + "customer-churn-model/Customer Churn Model.txt", "r")

# %%
cols = data3.readline().strip().split(",")
cols
# Out:
# ['State',
#  'Account Length',
#  'Area Code',
#  'Phone',
#  "Int'l Plan",
#  'VMail Plan',
#  'VMail Message',
#  'Day Mins',
#  'Day Calls',
#  'Day Charge',
#  'Eve Mins',
#  'Eve Calls',
#  'Eve Charge',
#  'Night Mins',
#  'Night Calls',
#  'Night Charge',
#  'Intl Mins',
#  'Intl Calls',
#  'Intl Charge',
#  'CustServ Calls',
#  'Churn?']

# %%
n_cols = len(cols)
n_cols
# Out:
# 21

# %%
counter = 0
main_dict = {}
for col in cols:
    main_dict[col] = []

# %%
for line in data3:
    values = line.strip().split(",")
    for i in range(len(cols)):
        main_dict[cols[i]].append(values[i])
    counter += 1
    
print("El data set tiene %d filas y %d columnas"%(counter, n_cols))
# Out:
# El data set tiene 3331 filas y 21 columnas

# %%
df3 = pd.DataFrame(main_dict)
df3.head()
# Out:
#   State Account Length Area Code     Phone Int'l Plan VMail Plan  \
# 0    NJ            137       415  358-1921         no         no
# 1    OH             84       408  375-9999        yes         no
# 2    OK             75       415  330-6626        yes         no
# 3    AL            118       510  391-8027        yes         no
# 4    MA            121       510  355-9993         no        yes
#
#   VMail Message    Day Mins Day Calls Day Charge   ...   Eve Calls Eve Charge  \
# 0             0  243.400000       114  41.380000   ...         110  10.300000
# 1             0  299.400000        71  50.900000   ...          88   5.260000
# 2             0  166.700000       113  28.340000   ...         122  12.610000
# 3             0  223.400000        98  37.980000   ...         101  18.750000
# 4            24  218.200000        88  37.090000   ...         108  29.620000
#
#    Night Mins Night Calls Night Charge  Intl Mins Intl Calls Intl Charge  \
# 0  162.600000         104     7.320000  12.200000          5    3.290000
# 1  196.900000          89     8.860000   6.600000          7    1.780000
# 2  186.900000         121     8.410000  10.100000          3    2.730000
# 3  203.900000         118     9.180000   6.300000          6    1.700000
# 4  212.600000         118     9.570000   7.500000          7    2.030000
#
#   CustServ Calls  Churn?
# 0              0  False.
# 1              2  False.
# 2              3  False.
# 3              0  False.
# 4              3  False.
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Lectura y escritura de ficheros

# %%
infile = mainpath +  "/" + "customer-churn-model/Customer Churn Model.txt"
outfile = mainpath +  "/" + "customer-churn-model/Tab Customer Churn Model.txt"

# %%
with open(infile, "r") as infile1:
    with open(outfile,"w") as outfile1:
        for line in infile1:
            fields = line.strip().split(",")
            outfile1.write("\t".join(fields))
            outfile1.write("\n")

# %%
df4 = pd.read_csv(outfile, sep = "\t")
df4.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge   ...    Eve Calls  \
# 0             25     265.1        110       45.07   ...           99
# 1             26     161.6        123       27.47   ...          103
# 2              0     243.4        114       41.38   ...          110
# 3              0     299.4         71       50.90   ...           88
# 4              0     166.7        113       28.34   ...          122
#
#    Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  \
# 0       16.78       244.7           91         11.01       10.0           3
# 1       16.62       254.4          103         11.45       13.7           3
# 2       10.30       162.6          104          7.32       12.2           5
# 3        5.26       196.9           89          8.86        6.6           7
# 4       12.61       186.9          121          8.41       10.1           3
#
#    Intl Charge  CustServ Calls  Churn?
# 0         2.70               1  False.
# 1         3.70               1  False.
# 2         3.29               0  False.
# 3         1.78               2  False.
# 4         2.73               3  False.
#
# [5 rows x 21 columns]

# %% [markdown]
# # Leer datos desde una URL

# %%
medals_url = "http://winterolympicsmedals.com/medals.csv"

# %%
medals_data = pd.read_csv(medals_url)
medals_data.head()
# Out:
#    Year      City       Sport      Discipline  NOC       Event Event gender  \
# 0  1924  Chamonix     Skating  Figure skating  AUT  individual            M
# 1  1924  Chamonix     Skating  Figure skating  AUT  individual            W
# 2  1924  Chamonix     Skating  Figure skating  AUT       pairs            X
# 3  1924  Chamonix   Bobsleigh       Bobsleigh  BEL    four-man            M
# 4  1924  Chamonix  Ice Hockey      Ice Hockey  CAN  ice hockey            M
#
#     Medal
# 0  Silver
# 1    Gold
# 2    Gold
# 3  Bronze
# 4    Gold

# %%
import urllib3
http = urllib3.PoolManager()
r = http.request('Get', "http://ip-api.com/json/13.89.57.7")
r.status
response = r.data

# %%
import csv
cr = csv.reader(response)

# %%
for row in cr:
    print(row)
    #Falta terminar
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-82-3d8bf9431c00> in <module>()
# ----> 1 for row in cr:
#       2     print(row)
#
# Error: iterator should return strings, not int (did you open the file in text mode?)

# %% [markdown]
# ## Ficheros XLS y XLSX

# %%
mainpath = "C:/Users/limc_/OneDrive/Documentos/GitHub/CursoPython/Luis/datasets"
filename = "titanic/titanic3.xls"
titanic2 = pd.read_excel(mainpath + "/" + filename, "titanic3")

# %%
filename = "titanic/titanic3.xlsx"
titanic3 = pd.read_excel(mainpath + "/" + filename, "titanic3")
titanic3.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %%
titanic3.to_csv(mainpath + "/titanic/titanic_custom.csv")
titanic3.to_excel(mainpath + "/titanic/titanic_custom.xls")
titanic3.to_json(mainpath + "/titanic/titanic_custom.json")

# %%
titanic3.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %%
pd.read_json(mainpath + "/titanic/titanic_custom.json")
# Out:
#       pclass  survived                                               name  \
# 0          1         1                      Allen, Miss. Elisabeth Walton
# 1          1         1                     Allison, Master. Hudson Trevor
# 10         1         0                             Astor, Col. John Jacob
# 100        1         1       Duff Gordon, Sir. Cosmo Edmund ("Mr Morgan")
# 1000       3         1                       McCormack, Mr. Thomas Joseph
# 1001       3         1                                 McCoy, Miss. Agnes
# 1002       3         1                                McCoy, Miss. Alicia
# 1003       3         1                                 McCoy, Mr. Bernard
# 1004       3         1                     McDermott, Miss. Brigdet Delia
# 1005       3         0                                McEvoy, Mr. Michael
# 1006       3         1                               McGovern, Miss. Mary
# 1007       3         1                        McGowan, Miss. Anna "Annie"
# 1008       3         0                           McGowan, Miss. Katherine
# 1009       3         0                                McMahon, Mr. Martin
# 101        1         0                       Dulles, Mr. William Crothers
# 1010       3         0                                  McNamee, Mr. Neal
# 1011       3         0                McNamee, Mrs. Neal (Eileen O'Leary)
# 1012       3         0                             McNeill, Miss. Bridget
# 1013       3         0                     Meanwell, Miss. (Marion Ogden)
# 1014       3         0            Meek, Mrs. Thomas (Annie Louise Rowley)
# 1015       3         0                                   Meo, Mr. Alfonzo
# 1016       3         0                                Mernagh, Mr. Robert
# 1017       3         1                           Midtsjo, Mr. Karl Albert
# 1018       3         0                                   Miles, Mr. Frank
# 1019       3         0                                   Mineff, Mr. Ivan
# 102        1         1              Earnshaw, Mrs. Boulton (Olive Potter)
# 1020       3         0                                 Minkoff, Mr. Lazar
# 1021       3         0                              Mionoff, Mr. Stoytcho
# 1022       3         0                                  Mitkoff, Mr. Mito
# 1023       3         1                  Mockler, Miss. Helen Mary "Ellie"
# ...      ...       ...                                                ...
# 972        3         0                                      Ling, Mr. Lee
# 973        3         0                                 Lithman, Mr. Simon
# 974        3         0                           Lobb, Mr. William Arthur
# 975        3         0    Lobb, Mrs. William Arthur (Cordelia K Stanlick)
# 976        3         0                                Lockyer, Mr. Edward
# 977        3         0                    Lovell, Mr. John Hall ("Henry")
# 978        3         1                                  Lulic, Mr. Nikola
# 979        3         0                        Lundahl, Mr. Johan Svensson
# 98         1         1        Douglas, Mrs. Walter Donald (Mahala Dutton)
# 980        3         1                           Lundin, Miss. Olga Elida
# 981        3         1                         Lundstrom, Mr. Thure Edvin
# 982        3         0                              Lyntakoff, Mr. Stanko
# 983        3         0                         MacKay, Mr. George William
# 984        3         1                   Madigan, Miss. Margaret "Maggie"
# 985        3         1                          Madsen, Mr. Fridtjof Arne
# 986        3         0                      Maenpaa, Mr. Matti Alexanteri
# 987        3         0                         Mahon, Miss. Bridget Delia
# 988        3         0                                    Mahon, Mr. John
# 989        3         0                                 Maisner, Mr. Simon
# 99         1         1  Duff Gordon, Lady. (Lucille Christiana Sutherl...
# 990        3         0                          Makinen, Mr. Kalle Edvard
# 991        3         1                                   Mamee, Mr. Hanna
# 992        3         0                                 Mangan, Miss. Mary
# 993        3         1                           Mannion, Miss. Margareth
# 994        3         0                            Mardirosian, Mr. Sarkis
# 995        3         0                                 Markoff, Mr. Marin
# 996        3         0                                 Markun, Mr. Johann
# 997        3         1                            Masselmani, Mrs. Fatima
# 998        3         0                               Matinoff, Mr. Nicola
# 999        3         1                  McCarthy, Miss. Catherine "Katie"
#
#          sex      age  sibsp  parch             ticket      fare    cabin  \
# 0     female  29.0000      0      0              24160  211.3375       B5
# 1       male   0.9167      1      2             113781  151.5500  C22 C26
# 10      male  47.0000      1      0           PC 17757  227.5250  C62 C64
# 100     male  49.0000      1      0           PC 17485   56.9292      A20
# 1000    male      NaN      0      0             367228    7.7500     None
# 1001  female      NaN      2      0             367226   23.2500     None
# 1002  female      NaN      2      0             367226   23.2500     None
# 1003    male      NaN      2      0             367226   23.2500     None
# 1004  female      NaN      0      0             330932    7.7875     None
# 1005    male      NaN      0      0              36568   15.5000     None
# 1006  female      NaN      0      0             330931    7.8792     None
# 1007  female  15.0000      0      0             330923    8.0292     None
# 1008  female  35.0000      0      0               9232    7.7500     None
# 1009    male      NaN      0      0             370372    7.7500     None
# 101     male  39.0000      0      0           PC 17580   29.7000      A18
# 1010    male  24.0000      1      0             376566   16.1000     None
# 1011  female  19.0000      1      0             376566   16.1000     None
# 1012  female      NaN      0      0             370368    7.7500     None
# 1013  female      NaN      0      0  SOTON/O.Q. 392087    8.0500     None
# 1014  female      NaN      0      0             343095    8.0500     None
# 1015    male  55.5000      0      0         A.5. 11206    8.0500     None
# 1016    male      NaN      0      0             368703    7.7500     None
# 1017    male  21.0000      0      0             345501    7.7750     None
# 1018    male      NaN      0      0             359306    8.0500     None
# 1019    male  24.0000      0      0             349233    7.8958     None
# 102   female  23.0000      0      1              11767   83.1583      C54
# 1020    male  21.0000      0      0             349211    7.8958     None
# 1021    male  28.0000      0      0             349207    7.8958     None
# 1022    male      NaN      0      0             349221    7.8958     None
# 1023  female      NaN      0      0             330980    7.8792     None
# ...      ...      ...    ...    ...                ...       ...      ...
# 972     male  28.0000      0      0               1601   56.4958     None
# 973     male      NaN      0      0      S.O./P.P. 251    7.5500     None
# 974     male  30.0000      1      0          A/5. 3336   16.1000     None
# 975   female  26.0000      1      0          A/5. 3336   16.1000     None
# 976     male      NaN      0      0               1222    7.8792     None
# 977     male  20.5000      0      0          A/5 21173    7.2500     None
# 978     male  27.0000      0      0             315098    8.6625     None
# 979     male  51.0000      0      0             347743    7.0542     None
# 98    female  48.0000      1      0           PC 17761  106.4250      C86
# 980   female  23.0000      0      0             347469    7.8542     None
# 981     male  32.0000      0      0             350403    7.5792     None
# 982     male      NaN      0      0             349235    7.8958     None
# 983     male      NaN      0      0         C.A. 42795    7.5500     None
# 984   female      NaN      0      0             370370    7.7500     None
# 985     male  24.0000      0      0            C 17369    7.1417     None
# 986     male  22.0000      0      0  STON/O 2. 3101275    7.1250     None
# 987   female      NaN      0      0             330924    7.8792     None
# 988     male      NaN      0      0          AQ/4 3130    7.7500     None
# 989     male      NaN      0      0           A/S 2816    8.0500     None
# 99    female  48.0000      1      0              11755   39.6000      A16
# 990     male  29.0000      0      0  STON/O 2. 3101268    7.9250     None
# 991     male      NaN      0      0               2677    7.2292     None
# 992   female  30.5000      0      0             364850    7.7500     None
# 993   female      NaN      0      0              36866    7.7375     None
# 994     male      NaN      0      0               2655    7.2292    F E46
# 995     male  35.0000      0      0             349213    7.8958     None
# 996     male  33.0000      0      0             349257    7.8958     None
# 997   female      NaN      0      0               2649    7.2250     None
# 998     male      NaN      0      0             349255    7.8958     None
# 999   female      NaN      0      0             383123    7.7500     None
#
#      embarked   boat   body                         home.dest
# 0           S      2    NaN                      St Louis, MO
# 1           S     11    NaN   Montreal, PQ / Chesterville, ON
# 10          C   None  124.0                      New York, NY
# 100         C      1    NaN                    London / Paris
# 1000        Q   None    NaN                              None
# 1001        Q     16    NaN                              None
# 1002        Q     16    NaN                              None
# 1003        Q     16    NaN                              None
# 1004        Q     13    NaN                              None
# 1005        Q   None    NaN                              None
# 1006        Q     13    NaN                              None
# 1007        Q   None    NaN                              None
# 1008        Q   None    NaN                              None
# 1009        Q   None    NaN                              None
# 101         C   None  133.0                  Philadelphia, PA
# 1010        S   None    NaN                              None
# 1011        S   None   53.0                              None
# 1012        Q   None    NaN                              None
# 1013        S   None    NaN                              None
# 1014        S   None    NaN                              None
# 1015        S   None  201.0                              None
# 1016        Q   None    NaN                              None
# 1017        S     15    NaN                              None
# 1018        S   None    NaN                              None
# 1019        S   None    NaN                              None
# 102         C      7    NaN         Mt Airy, Philadelphia, PA
# 1020        S   None    NaN                              None
# 1021        S   None    NaN                              None
# 1022        S   None    NaN                              None
# 1023        Q     16    NaN                              None
# ...       ...    ...    ...                               ...
# 972         S   None    NaN                              None
# 973         S   None    NaN                              None
# 974         S   None    NaN                              None
# 975         S   None    NaN                              None
# 976         S   None  153.0                              None
# 977         S   None    NaN                              None
# 978         S     15    NaN                              None
# 979         S   None    NaN                              None
# 98          C      2    NaN  Deephaven, MN / Cedar Rapids, IA
# 980         S     10    NaN                              None
# 981         S     15    NaN                              None
# 982         S   None    NaN                              None
# 983         S   None    NaN                              None
# 984         Q     15    NaN                              None
# 985         S     13    NaN                              None
# 986         S   None    NaN                              None
# 987         Q   None    NaN                              None
# 988         Q   None    NaN                              None
# 989         S   None    NaN                              None
# 99          C      1    NaN                    London / Paris
# 990         S   None    NaN                              None
# 991         C     15    NaN                              None
# 992         Q   None   61.0                              None
# 993         Q     16    NaN                              None
# 994         C   None    NaN                              None
# 995         C   None    NaN                              None
# 996         S   None    NaN                              None
# 997         C      C    NaN                              None
# 998         C   None    NaN                              None
# 999         Q  15 16    NaN                              None
#
# [1309 rows x 14 columns]

# %%
import pandas as pd
import io
import requests
url="https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"
s=requests.get(url).content
c=pd.read_csv(io.StringIO(s.decode('utf-8')))

url="https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"
c=pd.read_csv(url)

# %%
c.head()
# Out:
#     Country  Region
# 0   Algeria  AFRICA
# 1    Angola  AFRICA
# 2     Benin  AFRICA
# 3  Botswana  AFRICA
# 4   Burkina  AFRICA
