# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
a = 1
b = 100
n = 99
data = np.random.uniform(a,b,n)

# %%
# %matplotlib inline
plt.hist(data)
# Out:
# (array([10., 10., 16.,  5., 11., 11., 10.,  8.,  4., 14.]),
#  array([ 1.87985543, 11.66684853, 21.45384164, 31.24083474, 41.02782784,
#         50.81482095, 60.60181405, 70.38880716, 80.17580026, 89.96279336,
#         99.74978647]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## Distribucion normal

# %%
data = np.random.randn(100)

# %%
x = range(1,101)
plt.plot(x, data)

# %%
plt.hist(data)
# Out:
# (array([ 2.,  6.,  6., 17., 29., 14., 13.,  8.,  3.,  2.]),
#  array([-2.62023304, -2.08506704, -1.54990105, -1.01473505, -0.47956906,
#          0.05559694,  0.59076293,  1.12592893,  1.66109492,  2.19626092,
#          2.73142691]),
#  <a list of 10 Patch objects>)

# %%
mu = 5.5
sd = 2.5
data = mu + 2.5 * np.random.randn(100)
plt.hist(data)
# Out:
# (array([ 2.,  3.,  6., 11., 15., 17., 26., 12.,  2.,  6.]),
#  array([-1.44962446, -0.14709291,  1.15543865,  2.45797021,  3.76050177,
#          5.06303333,  6.36556489,  7.66809644,  8.970628  , 10.27315956,
#         11.57569112]),
#  <a list of 10 Patch objects>)

# %%
data = np.random.randn(2,4)
data
# Out:
# array([[-1.11512192, -2.10943066, -0.17553318,  0.75929847],
#        [-0.247491  , -0.68903792, -1.83805491,  0.26869089]])

# %% [markdown]
# # La simulacion de Monte Carlo

# %% [markdown]
# Generar dos numeros aleatorios x e y entre 0 y 1
# Calcularemos x * x + y * y
#  * Si el valor es inferior a 1 -> estamos dentro del circulo
#  * Si el valor es superior a 1 -> estamos fuera del circulo
# Calculamos el numero total de veces que estan dentro del circulo y lo dividimos entre el numero total de intentos para obtener
# una aproximacion de la probabilidad de caer dentro del circulo
# Usamos dicha probabilidad para aproximar el valor de pi
# Repetimos el experimento un numero suficiente de veces, para obtener diferentes aproximaciones de pi

# %%
pi_avg = 0
n = 99
pi_value_list = []
for i in range(100):
    value = 0
    x = np.random.uniform(0,1,n).tolist()
    y = np.random.uniform(0,1,n).tolist()
    for j in range(n): 
        z = np.sqrt(x[j] * x[j] + y[j] * y[j])
        if z <= 1:
            value += 1
    float_value = float(value)
    pi_value = float_value * 4 / n
    pi_value_list.append(pi_value)
    pi_avg += pi_value
    
pi = pi_avg / 100

print(pi)
plt.plot(pi_value_list)
# Out:
# 3.1450505050505035

# %% [markdown]
# ## Dummy Data Set

# %%
n = 99
data = pd.DataFrame(
    {
        'A' : np.random.randn(n),
        'B' : 1.5 + 2.5 * np.random.randn(n),
        'C' : np.random.uniform(5,32,n)
    }
)

# %%
data.head()
# Out:
#           A         B          C
# 0  0.148009 -0.145345  27.118817
# 1 -0.614803  8.201600  12.234072
# 2 -0.958820  1.555395  11.902790
# 3  0.232514  0.067916  11.829953
# 4  0.028717  5.807006  23.698842

# %%
data.describe()
# Out:
#                A          B          C
# count  99.000000  99.000000  99.000000
# mean    0.025444   1.685329  17.013974
# std     1.044542   2.642440   7.632691
# min    -2.489646  -3.812912   5.261262
# 25%    -0.695059   0.084879  10.692245
# 50%    -0.024142   1.505035  16.164771
# 75%     0.707044   3.875918  22.113145
# max     2.505912   8.139644  31.413693

# %%
filename = "../datasets/customer-churn-model/Customer Churn Model.txt"
data = pd.read_csv(filename)

# %%
colum_names = data.columns.values.tolist()

# %%
a = len(colum_names)
a
# Out:
# 21

# %%
new_data = pd.DataFrame(
    {
        'Column Name' : colum_names,
        'A'           : np.random.randn(a),
        'B'           : np.random.uniform(0,1,a)
    } # Index corrido, index = range(42, 42 + a) por si juntas un dataset con otro
)
new_data
# Out:
#        Column Name         A         B
# 0            State  1.560448  0.138118
# 1   Account Length -1.392251  0.834297
# 2        Area Code -3.049628  0.742377
# 3            Phone  0.486535  0.993843
# 4       Int'l Plan  0.300219  0.183407
# 5       VMail Plan  0.918945  0.869772
# 6    VMail Message  1.904157  0.863480
# 7         Day Mins -1.241883  0.558847
# 8        Day Calls  0.132390  0.036237
# 9       Day Charge  0.525521  0.868459
# 10        Eve Mins  1.086714  0.362638
# 11       Eve Calls -0.358991  0.113892
# 12      Eve Charge -0.947630  0.652593
# 13      Night Mins -0.518176  0.569816
# 14     Night Calls  0.327319  0.654551
# 15    Night Charge  0.146119  0.680604
# 16       Intl Mins -1.002578  0.353356
# 17      Intl Calls  1.800781  0.536981
# 18     Intl Charge -1.439358  0.510616
# 19  CustServ Calls -0.487438  0.815701
# 20          Churn? -0.114747  0.012544

# %%
new_data.head()
# Out:
#       Column Name         A         B
# 0           State  1.560448  0.138118
# 1  Account Length -1.392251  0.834297
# 2       Area Code -3.049628  0.742377
# 3           Phone  0.486535  0.993843
# 4      Int'l Plan  0.300219  0.183407
