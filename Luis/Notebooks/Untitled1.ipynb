# %%
import pandas as pd

# %%
data = pd.read_excel("datos base.xlsx")

# %%
data.head()
# Out:
#    DAP (cm)  H (m)  GE (ton/m3)  FEB  Indirecto (FF 0,5)  Indirecto (FF 0,45)  \
# 0         2    4.0          0.4  1.4            0.000352             0.000317
# 1         2    4.0          0.4  1.5            0.000377             0.000339
# 2         2    4.0          0.4  1.6            0.000402             0.000362
# 3         2    4.0          0.4  1.7            0.000427             0.000385
# 4         2    4.0          0.5  1.4            0.000440             0.000396
#
#    1.  CR-Segura 1999  2.  CR-Segura 1999  3.  CR-Mena 2008  4.  CR-Mena 2008  \
# 0                 NaN                 NaN               NaN               NaN
# 1                 NaN                 NaN               NaN               NaN
# 2                 NaN                 NaN               NaN               NaN
# 3                 NaN                 NaN               NaN               NaN
# 4                 NaN                 NaN               NaN               NaN
#
# ...

# %%
data.describe()
# Out:
#             DAP (cm)          H (m)    GE (ton/m3)            FEB  \
# count  194343.000000  194343.000000  194343.000000  194343.000000
# mean      156.238959      26.888548       0.550424       1.549801
# std        78.878868       7.108720       0.170651       0.111982
# min         2.000000       4.000000       0.300000       1.300000
# 25%        90.000000      22.500000       0.400000       1.400000
# 50%       157.000000      27.500000       0.600000       1.500000
# 75%       223.000000      32.000000       0.700000       1.600000
# max       300.000000      40.000000       0.800000       1.700000
#
#        Indirecto (FF 0,5)  Indirecto (FF 0,45)  1.  CR-Segura 1999  \
# count       194343.000000        194343.000000        32640.000000
# mean            30.816546            27.734891            4.406373
# std             30.266692            27.240023            1.398724
# min              0.000352             0.000317            2.136268
# ...

# %%
data.corr()
# Out:
#                               DAP (cm)     H (m)  GE (ton/m3)       FEB  \
# DAP (cm)                      1.000000  0.633966    -0.004641  0.003384
# H (m)                         0.633966  1.000000    -0.007171  0.005143
# GE (ton/m3)                  -0.004641 -0.007171     1.000000 -0.000517
# FEB                           0.003384  0.005143    -0.000517  1.000000
# Indirecto (FF 0,5)            0.854340  0.572754     0.313874  0.075137
# ...                                ...       ...          ...       ...
# 77. REG-Brown e Iverson 1992  0.975892  0.648476    -0.008949  0.006320
# 78. REG-Brown 1997            0.973788  0.607141    -0.005896  0.003910
# 79. REG-Chavé et al. 2014     0.863312  0.580434     0.314726  0.001499
# 80. REG-Chavé et al. 2014     0.858968  0.575733     0.316174  0.001473
# PROMEDIO                      0.956556  0.579564     0.096107  0.002085
#
#                               Indirecto (FF 0,5)  Indirecto (FF 0,45)  \
# ...
