# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
a = 1
b = 100
n = 999999999
data = np.random.uniform(a,b,n)

# %%
# %matplotlib inline
plt.hist(data)
# Out:
# (array([1.00014415e+08, 9.99919190e+07, 1.00000462e+08, 1.00005778e+08,
#         9.99999750e+07, 1.00006496e+08, 9.99773850e+07, 9.99989470e+07,
#         9.99978920e+07, 1.00006730e+08]),
#  array([ 1.00000015, 10.90000014, 20.80000012, 30.7000001 , 40.60000008,
#         50.50000006, 60.40000004, 70.30000002, 80.2       , 90.09999999,
#         99.99999997]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## Distribucion normal

# %%
data = np.random.randn(99999999)

# %%
x = range(1,101)
plt.plot(x, data)

# %%
plt.hist(data)
# Out:
# (array([ 2.,  9., 18., 26., 23., 13.,  8.,  0.,  0.,  1.]),
#  array([-2.30969221e+00, -1.73160411e+00, -1.15351602e+00, -5.75427920e-01,
#          2.66017717e-03,  5.80748274e-01,  1.15883637e+00,  1.73692447e+00,
#          2.31501257e+00,  2.89310066e+00,  3.47118876e+00]),
#  <a list of 10 Patch objects>)

# %%
mu = 5.5
sd = 2.5
data = mu + 2.5 * np.random.randn(10000)
plt.hist(data)
# Out:
# (array([   3.,   19.,  181.,  910., 2212., 2945., 2381., 1087.,  236.,
#           26.]),
#  array([-5.39532871, -3.42768229, -1.46003587,  0.50761054,  2.47525696,
#          4.44290338,  6.4105498 ,  8.37819621, 10.34584263, 12.31348905,
#         14.28113547]),
#  <a list of 10 Patch objects>)

# %%
data = np.random.randn(2,4)
data
# Out:
# array([[-1.06133748,  1.20928059, -1.15375666, -0.07509854],
#        [ 0.14383517, -1.26546304,  0.01984632,  0.20366228]])

# %% [markdown]
# # La simulacion de Monte Carlo

# %% [markdown]
# Generar dos numeros aleatorios x e y entre 0 y 1
# Calcularemos x * x + y * y
#  * Si el valor es inferior a 1 -> estamos dentro del circulo
#  * Si el valor es superior a 1 -> estamos fuera del circulo
# Calculamos el numero total de veces que estan dentro del circulo y lo dividimos entre el numero total de intentos para obtener
# una aproximacion de la probabilidad de caer dentro del circulo
# Usamos dicha probabilidad para aproximar el valor de pi
# Repetimos el experimento un numero suficiente de veces, para obtener diferentes aproximaciones de pi

# %%
pi_avg = 0
n = 99
pi_value_list = []
for i in range(100):
    value = 0
    x = np.random.uniform(0,1,n).tolist()
    y = np.random.uniform(0,1,n).tolist()
    for j in range(n): 
        z = np.sqrt(x[j] * x[j] + y[j] * y[j])
        if z <= 1:
            value += 1
    float_value = float(value)
    pi_value = float_value * 4 / n
    pi_value_list.append(pi_value)
    pi_avg += pi_value
    
pi = pi_avg / 100

print(pi)
plt.plot(pi_value_list)

# %% [markdown]
# ## Dummy Data Set

# %%
n = 99999
data = pd.DataFrame(
    {
        'A' : np.random.randn(n),
        'B' : 1.5 + 2.5 * np.random.randn(n),
        'C' : np.random.uniform(5,32,n)
    }
)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-43-ae9846f938cd> in <module>()
#       4         'A' : np.random.randn(n),
#       5         'B' : 1.5 + 2.5 * np.random.randn(n),
# ----> 6         'C' : np.random.uniform(5,32,n)
#       7     }
#       8 )
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     346                                  dtype=dtype, copy=copy)
#     347         elif isinstance(data, dict):
# --> 348             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     349         elif isinstance(data, ma.MaskedArray):
#     350             import numpy.ma.mrecords as mrecords
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\pandas\core\frame.py in _init_dict(self, data, index, columns, dtype)
#     457             arrays = [data[k] for k in keys]
#     458
# --> 459         return _arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     460
#     461     def _init_ndarray(self, values, index, columns, dtype=None, copy=False):
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\pandas\core\frame.py in _arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#    7321     axes = [_ensure_index(columns), _ensure_index(index)]
#    7322
# -> 7323     return create_block_manager_from_arrays(arrays, arr_names, axes)
#    7324
#    7325
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\pandas\core\internals.py in create_block_manager_from_arrays(arrays, names, axes)
#    4870
#    4871     try:
# -> 4872         blocks = form_blocks(arrays, names, axes)
#    4873         mgr = BlockManager(blocks, axes)
#    4874         mgr._consolidate_inplace()
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\pandas\core\internals.py in form_blocks(arrays, names, axes)
#    4904     blocks = []
#    4905     if len(items_dict['FloatBlock']):
# -> 4906         float_blocks = _multi_blockify(items_dict['FloatBlock'])
#    4907         blocks.extend(float_blocks)
#    4908
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\pandas\core\internals.py in _multi_blockify(tuples, dtype)
#    4993     for dtype, tup_block in grouper:
#    4994
# -> 4995         values, placement = _stack_arrays(list(tup_block), dtype)
#    4996
#    4997         block = make_block(values, placement=placement)
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\pandas\core\internals.py in _stack_arrays(tuples, dtype)
#    5035     shape = (len(arrays),) + _shape_compat(first)
#    5036
# -> 5037     stacked = np.empty(shape, dtype=dtype)
#    5038     for i, arr in enumerate(arrays):
#    5039         stacked[i] = _asarray_compat(arr)
#
# MemoryError:

# %%
data.head()
# Out:
#           A         B          C
# 0  0.148009 -0.145345  27.118817
# 1 -0.614803  8.201600  12.234072
# 2 -0.958820  1.555395  11.902790
# 3  0.232514  0.067916  11.829953
# 4  0.028717  5.807006  23.698842

# %%
data.describe()

# %%
filename = "../datasets/customer-churn-model/Customer Churn Model.txt"
data = pd.read_csv(filename)

# %%
colum_names = data.columns.values.tolist()

# %%
a = len(colum_names)
a
# Out:
# 21

# %%
new_data = pd.DataFrame(
    {
        'Column Name' : colum_names,
        'A'           : np.random.randn(a),
        'B'           : np.random.uniform(0,1,a)
    } # Index corrido, index = range(42, 42 + a) por si juntas un dataset con otro
)
new_data
# Out:
#        Column Name         A         B
# 42           State -0.462211  0.632605
# 43  Account Length -0.881617  0.755908
# 44       Area Code  2.241476  0.392830
# 45           Phone  0.566805  0.245384
# 46      Int'l Plan  0.837936  0.754530
# 47      VMail Plan  0.069822  0.474470
# 48   VMail Message -1.119693  0.580852
# 49        Day Mins -1.411329  0.881682
# 50       Day Calls -0.708956  0.292576
# 51      Day Charge -0.189829  0.192583
# 52        Eve Mins -0.412171  0.805189
# 53       Eve Calls -0.439074  0.782519
# 54      Eve Charge -1.573148  0.732352
# 55      Night Mins  2.058594  0.110468
# 56     Night Calls -0.336792  0.886890
# 57    Night Charge -0.418285  0.198150
# 58       Intl Mins -1.912605  0.385732
# 59      Intl Calls  0.606417  0.723412
# 60     Intl Charge  0.736948  0.052407
# 61  CustServ Calls -1.098651  0.447852
# 62          Churn? -0.352880  0.322550
