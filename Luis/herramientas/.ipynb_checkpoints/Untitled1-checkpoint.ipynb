# %%
import pandas as pd

# %%
data = pd.read_csv("VW_VOTARON_2012.csv", encoding = "ISO-8859-1", sep=";")

# %%
data.tail(10)
# Out:
#           CEDULA  DV NACIONALIDAD PAIS_NACIMIENTO       SEXO RANGO_EDAD  EDAD  \
# 13404699       0   0      chilena           Chile  masculino      35-39    37
# 13404700       0   0      chilena           Chile  masculino      25-29    26
# 13404701       0   0      chilena           Chile  masculino    18 a 19    18
# 13404702       0   0      chilena           Chile   femenino      20-24    22
# 13404703       0   0      chilena           Chile  masculino      35-39    36
# 13404704       0   0      chilena           Chile   femenino      25-29    26
# 13404705       0   0      chilena           Chile  masculino    18 a 19    18
# 13404706       0   0      chilena           Chile   femenino      20-24    22
# 13404707       0   0      chilena           Chile   femenino      20-24    21
# 13404708       0   0      chilena           Chile  masculino      40-44    40
#
#                       REGION    SUFRAGIO      PARTIDO  COMUNA  \
# ...

# %%
data_prueba = data["DV"] == 2

# %%
data_prueba.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: DV, dtype: bool

# %%
data_filtrada = data[data_prueba]
data_filtrada.head()
# Out:
# Empty DataFrame
# Columns: [CEDULA, DV, NACIONALIDAD, PAIS_NACIMIENTO, SEXO, RANGO_EDAD, EDAD, REGION, SUFRAGIO, PARTIDO, COMUNA, CIRCUNSCRIPCION, FECHA_INSCRIPCION, TIPO_INSCRIP, SEMANA, ANO]
# Index: []
