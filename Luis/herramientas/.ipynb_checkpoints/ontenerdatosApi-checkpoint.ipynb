# %%
import pandas as pd
import os
import requests

# %%
data = pd.read_json("https://fuentedatos.azurewebsites.net/VARIABLES_ORIGINALES/GetSubtemas/3")
data.head()
# Out:
#    id  subtema
# 0   3    Palta
# 1   4  limones

# %%
url = "http://www.google.com.mx/"

# %%
response = requests.get(url)

# %%
print(response)
# Out:
# <Response [200]>

# %%
response.status_code
# Out:
# 200

# %%
content = response.content
print(content)
# Out:
# b'<!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="es-419"><head><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/logos/doodles/2020/international-womens-day-2020-6753651837108310.2-l.png" itemprop="image"><meta content="D\xeda Internacional de la Mujer\xa02020" property="twitter:title"><meta content="\xa1Feliz D\xeda Internacional de la Mujer\xa02020! #GoogleDoodle #IWD2020" property="twitter:description"><meta content="\xa1Feliz D\xeda Internacional de la Mujer\xa02020! #GoogleDoodle #IWD2020" property="og:description"><meta content="summary_large_image" property="twitter:card"><meta content="@GoogleDoodles" property="twitter:site"><meta content="https://www.google.com/logos/doodles/2020/international-womens-day-2020-6753651837108310-2xa.gif" property="twitter:image"><meta content="https://www.google.com/logos/doodles/2020/international-womens-day-2020-6753651837108310-2xa.gif" property="og:image"><meta content="818" pro
# ...

# %%
pd.read_html("https://si3.bcentral.cl/SieteWS/sietews.asmx?wsdl").head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-f9238a89cd55> in <module>
# ----> 1 pd.read_html("https://si3.bcentral.cl/SieteWS/sietews.asmx?wsdl").head()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1103         na_values=na_values,
#    1104         keep_default_na=keep_default_na,
# -> 1105         displayed_only=displayed_only,
#    1106     )
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     910             break
#     911     else:
# --> 912         raise_with_traceback(retained)
#     913
#     914     ret = []
#
# ...

# %%
import requests
import json

response = requests.get('https://api.desarrolladores.energiaabierta.cl/indicadores-diarios/v1/dolar.json/?auth_key=80339514de6d66c4d39b992d22201ab3422d26e6')
data = response.json()['data']
#pd.read_json()
data_frame = pd.DataFrame(data)
data_frame
# Out:
#              0       1
# 0   04-01-2010   507.1
# 1   05-01-2010   505.7
# 2   06-01-2010  504.22
# 3   07-01-2010  497.93
# 4   08-01-2010  494.54
# 5   09-01-2010     NaN
# 6   10-01-2010     NaN
# 7   11-01-2010  492.37
# 8   12-01-2010  489.47
# 9   13-01-2010  491.16
# 10  14-01-2010  490.01
# 11  15-01-2010   493.0
# 12  16-01-2010     NaN
# 13  17-01-2010     NaN
# 14  18-01-2010   492.9
# 15  19-01-2010  490.89
# 16  20-01-2010  492.21
# 17  21-01-2010   495.2
# 18  22-01-2010  498.75
# 19  23-01-2010     NaN
# 20  24-01-2010     NaN
# 21  25-01-2010  506.36
# 22  26-01-2010  506.88
# 23  27-01-2010  512.12
# 24  28-01-2010  520.69
# 25  29-01-2010  531.75
# 26  30-01-2010     NaN
# 27  31-01-2010     NaN
# 28  01-02-2010   523.1
# 29  02-02-2010  528.48
# 30  03-02-2010  528.58
# 31  04-02-2010  535.51
# 32  05-02-2010  546.18
# 33  06-02-2010     NaN
# 34  07-02-2010     NaN
# 35  08-02-2010  543.35
# 36  09-02-2010  541.39
# 37  10-02-2010  541.23
# 38  11-02-2010  535.63
# ...

# %%
url = "https://api.desarrolladores.datos.gob.cl/indicadores-financieros/v1/dolar/periodo.json/?auth_key=80339514de6d66c4d39b992d22201ab3422d26e6&anioinicio=2000&mesinicio=01&diainicio=01&aniofin=2019&mesfin=12&diafin=30"
pd.read_json(url).head()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-22-593d97ba0651> in <module>
#       1 url = "https://api.desarrolladores.datos.gob.cl/indicadores-financieros/v1/dolar/periodo.json/?auth_key=80339514de6d66c4d39b992d22201ab3422d26e6&anioinicio=2000&mesinicio=01&diainicio=01&aniofin=2019&mesfin=12&diafin=30"
# ----> 2 pd.read_json(url).head()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\json\_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     567     compression = _infer_compression(path_or_buf, compression)
#     568     filepath_or_buffer, _, compression, should_close = get_filepath_or_buffer(
# --> 569         path_or_buf, encoding=encoding, compression=compression
#     570     )
#     571
#
# ...

# %%
response = requests.get('https://api.beta.datos.gob.cl/api/v2/datastreams/CUART-DE-CARAB/data.pjson/?auth_key=5f6adf1792f20e54a50a827c00079f18fdbf717b')
#response = requests.get('http://api.datos.sernac.cl/api/v2/datastreams/BASE-DE-RECLA-2016/data.json/?auth_key=5f6adf1792f20e54a50a827c00079f18fdbf717b&limit=50')
print(response.json())
data = response.json()['result']
#pd.read_json()
data_frame = pd.DataFrame(data)
data_frame
# Out:
# {'result': [{'': '4e007229b70f090dd4f3da67df0dad03', 'Latitud': '-18.4781864934462', 'Nombre-de-Via': 'SANTA MARIA', 'Nombre-Unidad': '1RA. COM. ARICA', 'Comuna': 'ARICA', 'Tipo-de-Via': 'AVENIDA', 'Numero-Direccion': '900', 'Region': 'REGION ARICA Y PARINACOTA', 'Tipo-de-Unidad': 'COMISARIA', 'Provincia': 'ARICA', 'Longitud': '-70.3116048841975'}, {'': '19b6f5e29f49c81be5ee2950a58c8ede', 'Latitud': '-18.195069385', 'Nombre-de-Via': 'RIQUELME', 'Nombre-Unidad': '2DA. COM. PUTRE', 'Comuna': 'PUTRE', 'Tipo-de-Via': 'CALLE', 'Numero-Direccion': '298', 'Region': 'REGION ARICA Y PARINACOTA', 'Tipo-de-Unidad': 'COMISARIA', 'Provincia': 'PARINACOTA', 'Longitud': '-69.5593510139999'}, {'': 'bf93f1772d2469dbd77638b6ce784178', 'Latitud': '-18.47043', 'Nombre-de-Via': 'AVENIDA LOA', 'Nombre-Unidad': '3RA. COM. ARICA', 'Comuna': 'ARICA', 'Tipo-de-Via': 'AVENIDA', 'Numero-Direccion': '1475', 'Region': 'REGION ARICA Y PARINACOTA', 'Tipo-de-Unidad': 'COMISARIA', 'Provincia': 'ARICA', 'Longitud': '-
# ...

# %%
pd.read_json("https://api.beta.datos.gob.cl/api/v2/datastreams/CUART-DE-CARAB/data.pjson/?auth_key=5f6adf1792f20e54a50a827c00079f18fdbf717b").head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-f2b8e80bdd0d> in <module>
# ----> 1 pd.read_json("https://api.beta.datos.gob.cl/api/v2/datastreams/CUART-DE-CARAB/data.pjson/?auth_key=5f6adf1792f20e54a50a827c00079f18fdbf717b").head()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\json\_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     590         return json_reader
#     591
# --> 592     result = json_reader.read()
#     593     if should_close:
#     594         try:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\json\_json.py in read(self)
#     715             obj = self._get_object_parser(self._combine_lines(data.split("\n")))
#     716         else:
# ...

# %%
response = requests.get('https://api.beta.datos.gob.cl/api/v2/datastreams/CUART-DE-CARAB/data.pjson/?auth_key=5f6adf1792f20e54a50a827c00079f18fdbf717b')
#response = requests.get('http://api.datos.sernac.cl/api/v2/datastreams/BASE-DE-RECLA-2016/data.json/?auth_key=5f6adf1792f20e54a50a827c00079f18fdbf717b&limit=50')
print(response.json())
data = response.json()['result']
#pd.read_json()
data_frame = pd.DataFrame(data)
data_frame
# Out:
# {'result': [{'': '4e007229b70f090dd4f3da67df0dad03', 'Latitud': '-18.4781864934462', 'Nombre-de-Via': 'SANTA MARIA', 'Nombre-Unidad': '1RA. COM. ARICA', 'Comuna': 'ARICA', 'Tipo-de-Via': 'AVENIDA', 'Numero-Direccion': '900', 'Region': 'REGION ARICA Y PARINACOTA', 'Tipo-de-Unidad': 'COMISARIA', 'Provincia': 'ARICA', 'Longitud': '-70.3116048841975'}, {'': '19b6f5e29f49c81be5ee2950a58c8ede', 'Latitud': '-18.195069385', 'Nombre-de-Via': 'RIQUELME', 'Nombre-Unidad': '2DA. COM. PUTRE', 'Comuna': 'PUTRE', 'Tipo-de-Via': 'CALLE', 'Numero-Direccion': '298', 'Region': 'REGION ARICA Y PARINACOTA', 'Tipo-de-Unidad': 'COMISARIA', 'Provincia': 'PARINACOTA', 'Longitud': '-69.5593510139999'}, {'': 'bf93f1772d2469dbd77638b6ce784178', 'Latitud': '-18.47043', 'Nombre-de-Via': 'AVENIDA LOA', 'Nombre-Unidad': '3RA. COM. ARICA', 'Comuna': 'ARICA', 'Tipo-de-Via': 'AVENIDA', 'Numero-Direccion': '1475', 'Region': 'REGION ARICA Y PARINACOTA', 'Tipo-de-Unidad': 'COMISARIA', 'Provincia': 'ARICA', 'Longitud': '-
# ...

# %%
pd.read_csv("https://api.beta.datos.gob.cl/api/v2/datastreams/BASE-DE-RECLA-2015/data.csv/?auth_key=5f6adf1792f20e54a50a827c00079f18fdbf717b&format=csv").head()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-48-7015701b7056> in <module>
# ----> 1 pd.read_csv("https://api.beta.datos.gob.cl/api/v2/datastreams/BASE-DE-RECLA-2015/data.csv/?auth_key=5f6adf1792f20e54a50a827c00079f18fdbf717b&format=csv").head()
#
# ...

# %%
pd.read_csv("https://beta.datos.gob.cl/rest/datastreams/259435/data.csv").head()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-51-1888ca41b9ed> in <module>
# ----> 1 pd.read_csv("https://beta.datos.gob.cl/rest/datastreams/259435/data.csv").head()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# ...

# %%
# Out:
# 1
